# %% [markdown]
# <a href="https://colab.research.google.com/github/Adeeba21Fatima/mavenprojecte2eautomation/blob/machine-learning-projects/Wholesale_Cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
data = pd.read_csv("/content/Wholesale customers data.csv")

# %%
data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
import scipy.cluster.hierarchy as sch
plt.title("Wholesale Cluster Dendrogram")
dendrogram = sch.dendrogram(sch.linkage(data,method='ward'))
